# %%
import logging as lg

# %%
lg.basicConfig(filename = 'logging/assign_12.log' , level = lg.DEBUG , format = '%(asctime)s %(levelname)s %(message)s')

# %% [markdown]
# #### 1. For this challenge, forget how to add two numbers together. The best explanation on what to do for this function is this meme:
#
# ![assign_12.jpg](attachment:assign_12.jpg)
#
# Examples
#
# meme_sum(26, 39) ➞ 515
#
# #2+3 = 5, 6+9 = 15
#
# #26 + 39 = 515
#
# meme_sum(122, 81) ➞ 1103
#
# #1+0 = 1, 2+8 = 10, 2+1 = 3
#
# #122 + 81 = 1103
#
# meme_sum(1222, 30277) ➞ 31499

# %%
def meme_sum(a,b):
    lg.info("numbers: " +str(a) +str(b))
    try:
        total = []
        t = ''
        while a >0 or b > 0:
            total.append(a %10 + b % 10)
            a = a // 10
            b = b // 10
        lg.info("Computed Successfully")
        return(''.join(map(str,total[::-1])))
    except Exception as e:
        lg.error("Error Occured : " +str(e))
        return "Error Occured : " ,e

# %%
meme_sum(1222, 30277)
# Out:
# '31499'

# %% [markdown]
# #### 2. Given an integer, create a function that returns the next prime. If the number is prime, return the number itself.
#
# Examples
#
# next_prime(12) ➞ 13
#
# next_prime(24) ➞ 29
#
# next_prime(11) ➞ 11
#
# #11 is a prime, so we return the number itself.

# %%
lg.info("\n\n Question2 \n")

def next_prime(n):
    lg.info(str(n))
    
    try:
        flag = 0
        for i in range(2,(n//2)+1):
            if n % i == 0:
                return next_prime(n+1)
            else:
                flag = 1
        if flag == 1:
            lg.info("Executed Successfully")
            return n
    
    except Exception as e:
        lg.error("Error Occured : " +str(e))
        return "Error Occurred : " ,e

# %%
next_prime(12)
# Out:
# 13

# %%
next_prime(11)
# Out:
# 11

# %% [markdown]
# #### 3. If a person traveled up a hill for 18mins at 20mph and then traveled back down the same path at 60mph then their average speed traveled was 30mph.
#
# Write a function that returns the average speed traveled given an uphill time, uphill rate and a downhill rate. Uphill time is given in minutes. Return the rate as an integer (mph). No rounding is necessary.
#
# Examples
#
# ave_spd(18, 20, 60) ➞ 30
#
# ave_spd(30, 10, 30) ➞ 15
#
# ave_spd(30, 8, 24) ➞ 12

# %%
lg.info("\n\n Question 3 \n")

def ave_spd(t,x,y):
    lg.info("2 speeds are : " +str(x) + ',' + str(y))
    try : 
        spd = int((2 *x*y)/(x+y))
        lg.info("avg speed is : " +str(spd))
        return spd
    except Exception as e:
        lg.error("Error Occurred : " +str(e))
        return "Error Occured :" , e

# %%
ave_spd(30, 8, 24)
# Out:
# 12

# %% [markdown]
# #### 4. The Kempner Function, applied to a composite number, permits to find the smallest integer greater than zero whose factorial is exactly divided by the number.
#
# kempner(6) ➞ 3
#
# 1! = 1 % 6 > 0
#
# 2! = 2 % 6 > 0
#
# 3! = 6 % 6 === 0
#
# kempner(10) ➞ 5
#
# 1! = 1 % 10 > 0
#
# 2! = 2 % 10 > 0
#
# 3! = 6 % 10 > 0
#
# 4! = 24 % 10 > 0
#
# 5! = 120 % 10 === 0
#
# A Kempner Function applied to a prime will always return the prime itself.
#
# kempner(2) ➞ 2
#
# kempner(5) ➞ 5
#
# Given an integer n, implement a Kempner Function.
#
# Examples
#
# kempner(6) ➞ 3
#
# kempner(10) ➞ 5
#
# kempner(2) ➞ 2

# %%
lg.info("\n\n Question 4 \n")
def fact(num):
    
    try:
        
        f =1
        while num > 1:
            f *= num * (num-1)
            num -= 1
        
        return int(f)
    
    except Exception as e:
        return e

def kempner(n):
    lg.info("num is : " +str(n))
    try:
        for i in range(2,n+1):
            if fact(i) % n == 0:
                lg.info("answer is : " +str(i))
                return i
                
    except Exception as e:
        lg.error("Error Occured : " +str(e))
        return e

# %%
kempner(10)
# Out:
# 5

# %%
kempner(3)
# Out:
# 3

# %% [markdown]
# #### 5. You work in a factory, and your job is to take items from a conveyor belt and pack them into boxes. Each box can hold a maximum of 10 kgs. Given a list containing the weight (in kg) of each item, how many boxes would you need to pack all of the items?
#
# Example
#
# boxes([2, 1, 2, 5, 4, 3, 6, 1, 1, 9, 3, 2]) ➞ 5
#
# #Box 1 = [2, 1, 2, 5] (10kg)
#
# #Box 2 = [4, 3] (7kg)
#
# #Box 3 = [6, 1, 1] (8kg)
#
# #Box 4 = [9] (9kg)
#
# #Box 5 = [3, 2] (5kg)

# %%
lg.info("\n\n Question 5\n")
def boxes(lst):
    lg.info("conveyor belt : " +str(lst))
    try:
        box = 0
        count = 0
        for i in lst:
            count += i
            if count > 10:
                box += 1
                count = 0
                count += i
            
        if count > 0:
            lg.info("Boxes = " +str(box + 1))
            return box + 1 
        else:
            lg.info("Boxes = " +str(box))
            return box
    
    except Exception as e:
        lg.error(str(e))
        return e

# %%
boxes([2, 1, 2, 5, 4, 3, 6, 1, 1, 9, 3, 2])
# Out:
# 5
